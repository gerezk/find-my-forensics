# %%
import folium

# %% [markdown]
# # Train travel from Vienna to Ukraine
#
# The notebook attempts to trace the route taken by the target from Vienna, Austria to Kyiv, Ukraine (July 2-3). Exact information on addresses and some routes taken, along with modes of transportation, are known, but they have been anonymized to comply with privacy laws.
#
# The train taken from Vienna, Austria to Chop, Ukraine and its schedule is known due to correlating Find My location reports to a live maps and timetables of trains in Hungary. The exact train taken from Chop to Kyiv could not be correlated to a train on the published timetables: https://www.uz.gov.ua/en/passengers/timetable/. A possible train was correlated with low confidence, but this was made on the assumption that it was severely delayed. No direct evidence supporting this assumption exists, but there was news reporting that a Russian air assault severely delayed trains in the east of the country the night of July 2: https://hmh.news/en/34839/due-to-shelling-of-kyiv-41-ukrainian-railways-trains-are-delayed/amp/.
#
# ### Limitations
#
# - Find My does not provide historical location data; a user must persistently monitor the app to try and build this location history. Some locations or movements could then be missing.
#
# ### Interpreting the map
#
# - Hover over an element to get a description.
# - Click on an element to show the date or time indicating when the AirPods were at a location or when travel occurred.
# - A dotted line indicates that the route details are not fully known. A solid line symbolizes that all route details are known.

# %%
m = folium.Map(location=(49.2074, 23.1393),
               zoom_start=6)

# --- Wien Meidling ---
meidling_coords = [48.1745, 16.3341]
folium.Marker(
    location=meidling_coords,
    tooltip="Wien Meidling",
    popup="Morning of July 2",
    icon=folium.Icon(color="green", icon="train", prefix="fa"),
).add_to(m)

# --- Chop, Ukraine ---
chop_coords = [48.4324, 22.2055]
folium.Marker(
    location=chop_coords,
    tooltip="Chop, Ukraine",
    popup="Evening of July 2",
    icon=folium.Icon(color="green", icon="random", prefix="glyphicon"),
).add_to(m)
# --- Wien Meidling -> Chop, Ukraine ---
folium.PolyLine(
    locations=[meidling_coords, chop_coords],
    tooltip="Wien Meidling -> Chop, Ukraine",
    color="red",
    weight=3,
    opacity=0.8,
).add_to(m)

# --- Krasne, Ukraine ---
krasne_coords = [49.9179, 24.6134]
folium.Marker(
    location=krasne_coords,
    tooltip="Krasne, Ukraine",
    popup="Morning of July 3",
    icon=folium.Icon(color="green", icon="train", prefix="fa"),
).add_to(m)
# --- Chop, Ukraine -> Krasne, Ukraine ---
folium.PolyLine(
    locations=[chop_coords, krasne_coords],
    tooltip="Chop, Ukraine -> Krasne, Ukraine",
    color="red",
    weight=3,
    opacity=0.8,
    dash_array="5, 10"   # 5 px line, 10 px gap
).add_to(m)

# --- Sytne, Ukraine ---
sytne_coords = [50.1762, 25.4329]
folium.Marker(
    location=sytne_coords,
    tooltip="Sytne, Ukraine",
    popup="Morning of July 3",
    icon=folium.Icon(color="green", icon="train", prefix="fa"),
).add_to(m)
# --- Krasne, Ukraine -> Sytne, Ukraine ---
folium.PolyLine(
    locations=[krasne_coords, sytne_coords],
    tooltip="Krasne, Ukraine -> Sytne, Ukraine",
    color="red",
    weight=3,
    opacity=0.8,
    dash_array="5, 10"   # 5 px line, 10 px gap
).add_to(m)

# --- Staryi Kryvyn, Ukraine ---
staryi_kryvyn_coords = [50.3494, 26.7077]
folium.Marker(
    location=staryi_kryvyn_coords,
    tooltip="Staryi Kryvyn, Ukraine",
    popup="Morning of July 3",
    icon=folium.Icon(color="green", icon="train", prefix="fa"),
).add_to(m)
# --- Sytne, Ukraine -> Staryi Kryvyn, Ukraine ---
folium.PolyLine(
    locations=[sytne_coords, staryi_kryvyn_coords],
    tooltip="Sytne, Ukraine -> Staryi Kryvyn, Ukraine",
    color="red",
    weight=3,
    opacity=0.8,
    dash_array="5, 10"   # 5 px line, 10 px gap
).add_to(m)

# --- Shepetivka, Ukraine ---
shepetivka_coords = [50.1980, 27.0684]
folium.Marker(
    location=shepetivka_coords,
    tooltip="Shepetivka, Ukraine",
    popup="Morning of July 3",
    icon=folium.Icon(color="green", icon="train", prefix="fa"),
).add_to(m)
# --- Staryi Kryvyn, Ukraine -> Shepetivka, Ukraine ---
folium.PolyLine(
    locations=[staryi_kryvyn_coords, shepetivka_coords],
    tooltip="Staryi Kryvyn, Ukraine -> Shepetivka, Ukraine",
    color="red",
    weight=3,
    opacity=0.8,
    dash_array="5, 10"   # 5 px line, 10 px gap
).add_to(m)

# --- Blydni, Ukraine ---
blydni_coords = [50.1107, 27.5813]
folium.Marker(
    location=blydni_coords,
    tooltip="Blydni, Ukraine",
    popup="Morning of July 3",
    icon=folium.Icon(color="green", icon="train", prefix="fa"),
).add_to(m)
# --- Shepetivka, Ukraine -> Blydni, Ukraine ---
folium.PolyLine(
    locations=[shepetivka_coords, blydni_coords],
    tooltip="Shepetivka, Ukraine -> Blydni, Ukraine",
    color="red",
    weight=3,
    opacity=0.8,
    dash_array="5, 10"   # 5 px line, 10 px gap
).add_to(m)

# --- Pechanivka, Ukraine ---
pechanivka_coords = [50.0758, 27.8038]
folium.Marker(
    location=pechanivka_coords,
    tooltip="Pechanivka, Ukraine",
    popup="Morning of July 3",
    icon=folium.Icon(color="green", icon="train", prefix="fa"),
).add_to(m)
# --- Blydni, Ukraine -> Pechanivka, Ukraine ---
folium.PolyLine(
    locations=[blydni_coords, pechanivka_coords],
    tooltip="Blydni, Ukraine -> Pechanivka, Ukraine",
    color="red",
    weight=3,
    opacity=0.8,
    dash_array="5, 10"   # 5 px line, 10 px gap
).add_to(m)

# --- Berdychiv, Ukraine ---
berdychiv_coords = [49.8898, 28.6129]
folium.Marker(
    location=berdychiv_coords,
    tooltip="Berdychiv, Ukraine",
    popup="Morning of July 3",
    icon=folium.Icon(color="green", icon="train", prefix="fa"),
).add_to(m)
# --- Pechanivka, Ukraine -> Berdychiv, Ukraine ---
folium.PolyLine(
    locations=[pechanivka_coords, berdychiv_coords],
    tooltip="Pechanivka, Ukraine -> Berdychiv, Ukraine",
    color="red",
    weight=3,
    opacity=0.8,
    dash_array="5, 10"   # 5 px line, 10 px gap
).add_to(m)

# --- Kalynivka, Ukraine ---
kalynivka_coords = [50.2353, 30.2498]
folium.Marker(
    location=kalynivka_coords,
    tooltip="Kalynivka, Ukraine",
    popup="Afternoon of July 3",
    icon=folium.Icon(color="green", icon="train", prefix="fa"),
).add_to(m)
# --- Berdychiv, Ukraine -> Kalynivka, Ukraine ---
folium.PolyLine(
    locations=[berdychiv_coords, kalynivka_coords],
    tooltip="Berdychiv, Ukraine -> Kalynivka, Ukraine",
    color="red",
    weight=3,
    opacity=0.8,
    dash_array="5, 10"   # 5 px line, 10 px gap
).add_to(m)

# --- Kyiv-Pasazhyrskyi ---
kyiv_pas_coords = [50.4404, 30.4898]
folium.Marker(
    location=kyiv_pas_coords,
    tooltip="Kyiv-Pasazhyrskyi",
    popup="Afternoon of July 3",
    icon=folium.Icon(color="green", icon="person-running", prefix="fa"),
).add_to(m)
# --- Kalynivka, Ukraine -> Kyiv-Pasazhyrskyi ---
folium.PolyLine(
    locations=[kalynivka_coords, kyiv_pas_coords],
    tooltip="Kalynivka, Ukraine -> Kyiv-Pasazhyrskyi",
    color="red",
    weight=3,
    opacity=0.8,
    dash_array="5, 10"   # 5 px line, 10 px gap
).add_to(m)

# --- suspected residence ---
residence_coords = [50.4964, 30.5208]
folium.Marker(
    location=residence_coords,
    tooltip="Suspected Residential Address",
    popup="July 3",
    icon=folium.Icon(color="orange", icon="home"),
).add_to(m)
# uncertainty radius
folium.Circle(
    location=residence_coords,
    radius=500,
    color="orange",
    weight=2,
    fill=True,
    fill_color="orange",
    fill_opacity=0.2
).add_to(m)
# --- Kyiv-Pasazhyrskyi -> suspected residence ---
folium.PolyLine(
    locations=[kyiv_pas_coords, residence_coords],
    tooltip="Kyiv-Pasazhyrskyi -> Suspected Residence",
    color="red",
    weight=3,
    opacity=0.8,
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0ff20c1029c8d3c5698f933609b7615f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0ff20c1029c8d3c5698f933609b7615f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0ff20c1029c8d3c5698f933609b7615f = L.map(
#                 &quot;map_0ff20c1029c8d3c5698f933609b7615f&quot;,
#                 {
#                     center: [49.2074, 23.1393],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6b542b04ddb363d7384e5744581b242c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6b542b04ddb363d7384e5744581b242c.addTo(map_0ff20c1029c8d3c5698f933609b7615f);
#
#
#             var marker_8f22d10cdd70f7b154d40d6c29427c58 = L.marker(
#                 [48.1745, 16.3341],
#                 {
# }
#             ).addTo(map_0ff20c1029c8d3c5698f933609b7615f);
#
#
#             var icon_64b20454cfaa1a5ef8fb562e77dd3474 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;train&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_269f0ab6e343b125c7cd61a2a665c001 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bd69306192d62ea75d50a599c175964c = $(`&lt;div id=&quot;html_bd69306192d62ea75d50a599c175964c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Morning of July 2&lt;/div&gt;`)[0];
#                 popup_269f0ab6e343b125c7cd61a2a665c001.setContent(html_bd69306192d62ea75d50a599c175964c);
#
#
#
#         marker_8f22d10cdd70f7b154d40d6c29427c58.bindPopup(popup_269f0ab6e343b125c7cd61a2a665c001)
#         ;
#
#
#
#
#             marker_8f22d10cdd70f7b154d40d6c29427c58.bindTooltip(
#                 `&lt;div&gt;
#                      Wien Meidling
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_8f22d10cdd70f7b154d40d6c29427c58.setIcon(icon_64b20454cfaa1a5ef8fb562e77dd3474);
#
#
#             var marker_ca53b099bec89ff5d8b162dd4dd62903 = L.marker(
#                 [48.4324, 22.2055],
#                 {
# }
#             ).addTo(map_0ff20c1029c8d3c5698f933609b7615f);
#
#
#             var icon_0b2ab35defb782ce0dc19be99d244e67 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;random&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_a3020cd267bba886e1eb5f564404b891 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_555ec9972e62c89a0697ea322f6673dc = $(`&lt;div id=&quot;html_555ec9972e62c89a0697ea322f6673dc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Evening of July 2&lt;/div&gt;`)[0];
#                 popup_a3020cd267bba886e1eb5f564404b891.setContent(html_555ec9972e62c89a0697ea322f6673dc);
#
#
#
#         marker_ca53b099bec89ff5d8b162dd4dd62903.bindPopup(popup_a3020cd267bba886e1eb5f564404b891)
#         ;
#
#
#
#
#             marker_ca53b099bec89ff5d8b162dd4dd62903.bindTooltip(
#                 `&lt;div&gt;
#                      Chop, Ukraine
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_ca53b099bec89ff5d8b162dd4dd62903.setIcon(icon_0b2ab35defb782ce0dc19be99d244e67);
#
#
#             var poly_line_63f25930a956bfe47be6f179d750d619 = L.polyline(
#                 [[48.1745, 16.3341], [48.4324, 22.2055]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.8, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0ff20c1029c8d3c5698f933609b7615f);
#
#
#             poly_line_63f25930a956bfe47be6f179d750d619.bindTooltip(
#                 `&lt;div&gt;
#                      Wien Meidling -&gt; Chop, Ukraine

# %%
m.save("../maps/vienna_kyiv.html")
