# %%
import folium

# %% [markdown]
# # Pattern-of-life (PoL) Analysis
#
# The purpose of this notebook is to demonstrate and visualize a case study in applying techniques for pattern-of-life analysis of a target given Find My location data. The specific case is that someone stole a pair of Airpods 4 with active noice cancellation (ANC). An interesting feature of this model is that it has built-in case speakers, enabling someone on the Find My app to play a sound while the airpods are in the case. Exact addresses and some routes taken, along with modes of transportation, are known, but they have been anonymized to comply with privacy laws.
#
# ### Interpreting the map
#
# - Hover over an element to get a description.
# - Click on an element to show the date or time indicating when the AirPods were at a location or when travel occurred.

# %% [markdown]
# ## June 28
#
# Theft occurs on a train at approximately 11:30, most likely at Wien Hbf. The theft went unnoticed for about two hours before the Find My app was checked for the first time, where the AirPods were then located at a residential address in the 16th district (Ottakring). Therefore, the route taken by the thief to the address is unknown.

# %%
m = folium.Map(location=(48.2085, 16.3721),
               zoom_start=13)

# --- location of theft ----
theft_coords = [48.1848, 16.3782]
folium.Marker(
    location=theft_coords,
    tooltip="Site of Theft - Wien Hbf",
    popup="~11:30 at June 28",
    icon=folium.Icon(color="red", icon="flag"),
).add_to(m)

# --- suspected residential address in Ottakring ---
ottakring_coords = [48.2128, 16.3178]
folium.Marker(
    location=ottakring_coords,
    tooltip="Suspected Residential Address",
    popup="June 28-29",
    icon=folium.Icon(color="orange", icon="home"),
).add_to(m)
# uncertainty radius
folium.Circle(
    location=ottakring_coords,
    radius=500,
    color="orange",
    weight=2,
    fill=True,
    fill_color="orange",
    fill_opacity=0.2
).add_to(m)

# --- add unknown route ---
folium.PolyLine(
    locations=[theft_coords, ottakring_coords],
    tooltip="Unknown route",
    popup="Afternoon of June 28",
    color="red",
    weight=3,
    opacity=0.8,
    dash_array="5, 10"   # 5 px line, 10 px gap
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_71d45bbe804f0619446a1a2f8648d8e5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_71d45bbe804f0619446a1a2f8648d8e5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_71d45bbe804f0619446a1a2f8648d8e5 = L.map(
#                 &quot;map_71d45bbe804f0619446a1a2f8648d8e5&quot;,
#                 {
#                     center: [48.2085, 16.3721],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2590c4d1228da2879e5919ae9a4ca28a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2590c4d1228da2879e5919ae9a4ca28a.addTo(map_71d45bbe804f0619446a1a2f8648d8e5);
#
#
#             var marker_8d0e2dab10ffca7ce2c7e08d794974fc = L.marker(
#                 [48.1848, 16.3782],
#                 {
# }
#             ).addTo(map_71d45bbe804f0619446a1a2f8648d8e5);
#
#
#             var icon_5b755af34af6e6bc4ddab78d1b706075 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;flag&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_35bfd61f0be044e6601ad10c254754ed = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_54236d408bab55df1dd13a56875892df = $(`&lt;div id=&quot;html_54236d408bab55df1dd13a56875892df&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;~11:30 at June 28&lt;/div&gt;`)[0];
#                 popup_35bfd61f0be044e6601ad10c254754ed.setContent(html_54236d408bab55df1dd13a56875892df);
#
#
#
#         marker_8d0e2dab10ffca7ce2c7e08d794974fc.bindPopup(popup_35bfd61f0be044e6601ad10c254754ed)
#         ;
#
#
#
#
#             marker_8d0e2dab10ffca7ce2c7e08d794974fc.bindTooltip(
#                 `&lt;div&gt;
#                      Site of Theft - Wien Hbf
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_8d0e2dab10ffca7ce2c7e08d794974fc.setIcon(icon_5b755af34af6e6bc4ddab78d1b706075);
#
#
#             var marker_ca603c529d0001ce56cea6bed0b4d524 = L.marker(
#                 [48.2128, 16.3178],
#                 {
# }
#             ).addTo(map_71d45bbe804f0619446a1a2f8648d8e5);
#
#
#             var icon_0a6a6af11fd55fee75ed367a71c00e3e = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;orange&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;home&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_3f8d4c282ff1cf13db99bfc7ecffeb0f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cd4547202de3459efaf85c1744f08787 = $(`&lt;div id=&quot;html_cd4547202de3459efaf85c1744f08787&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;June 28-29&lt;/div&gt;`)[0];
#                 popup_3f8d4c282ff1cf13db99bfc7ecffeb0f.setContent(html_cd4547202de3459efaf85c1744f08787);
#
#
#
#         marker_ca603c529d0001ce56cea6bed0b4d524.bindPopup(popup_3f8d4c282ff1cf13db99bfc7ecffeb0f)
#         ;
#
#
#
#
#             marker_ca603c529d0001ce56cea6bed0b4d524.bindTooltip(
#                 `&lt;div&gt;
#                      Suspected Residential Address
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_ca603c529d0001ce56cea6bed0b4d524.setIcon(icon_0a6a6af11fd55fee75ed367a71c00e3e);
#
#
#             var circle_06c866ace55d114b164c51f95b5b1584 = L.circle(
#                 [48.2128, 16.3178],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;orange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;orange&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 500, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_71d45bbe804f0619446a1a2f8648d8e5);
#
#
#             var poly_line_a7c3e852c29016c7a4f815966336e17d = L.polyline(
#                 [[48.1848, 16.3782], [48.2128, 16.3178]],
#                 {&quot;bubblingMouseEvents&quot;: true,

# %%
m.save("AirPods_PoL.html")
